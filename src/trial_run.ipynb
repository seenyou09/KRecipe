# %%
import pandas as pd
import nltk

df = pd.read_excel('/Users/seanyoo/Desktop/korean_food_project/data/koreanFood_data.xlsx')
df = df.drop("Unnamed: 0", axis=1)
df =df.dropna()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       2 import nltk
# ----> 4 df = pd.read_excel('/Users/seanyoo/Desktop/korean_food_project/data/koreanFood_data.xlsx')
#       5 df = df.drop("Unnamed: 0", axis=1)
#       6 df =df.dropna()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
def clean_text(ingredient_str):
    
    ingredient_list = [item.strip(" '") for item in ingredient_str.strip("[]").split(",")]
    return ingredient_list

df['Ingredients'] = df['Ingredients'].apply(clean_text)
df['Type'] = df['Type'].apply(clean_text)

# %%
#we find the most common words and 
vocabulary = nltk.FreqDist()



for ingredient_list in df['Ingredients']:
    for ingredients in ingredient_list:
        ingredients = ingredients.split(",")
        vocabulary.update(ingredients)
for word, frequency in vocabulary.most_common(200)[1:]:
    print(f'{word}: {frequency}')

#from this list we have a list of common ingredients to get ride of:
remove_word_list = ["kosher salt", 'toasted seasame oil', "water", "sugar", "soy sauce","vegetable oil","ground black pepper", "hot pepper flakes","flour", "honey","vinegar"]
# Out:
# garlic: 1105
# kosher salt: 1080
# toasted sesame oil: 915
# onion: 829
# green onion: 816
# water: 792
# sugar: 726
# soy sauce: 724
# vegetable oil: 640
# ground black pepper: 542
# hot pepper flakes: 525
# eggs: 398
# sesame seeds: 394
# green chili pepper: 368
# flour: 316
# ginger: 310
# carrot: 304
# gochujang: 297
# toasted sesame seeds: 277
# honey: 273
# fish sauce: 267
# vinegar: 254
# rice syrup: 250
# rice: 208
# Korean radish: 186
# potato starch: 180
# pine nuts: 147
# dried anchovies: 138
# cucumber: 133
# doenjang: 132
# daikon radish: 129
# red chili pepper: 128
# kimchi: 119
# Asian chives: 114
# tofu: 114
# gim: 111
# Korean pear: 108
# dried kelp: 107
# shrimp: 102
# pork belly: 102
# brown sugar: 101
# english cucumber: 98
# corn syrup: 94
# zucchini: 88
# cooking oil: 86
# large green onion: 86
# sweet rice flour: 85
# beef: 85
# shiitake mushrooms: 80
# lettuce: 77
# jujubes: 76
# sweet potato starch noodles: 70
# white sugar: 69
# cabbage: 68
# ...

# %%
def ingredinent_parser(ingredients):
    remove_word_list = ["kosher salt", 'toasted seasame oil', "water", "sugar", "soy sauce","vegetable oil","ground black pepper", "hot pepper flakes","flour", "honey","vinegar"]
    ingred_list = []
    for ingred in ingredients:
        #ingred.translate(translator)
        if ingred not in remove_word_list:
            ingred_list.append(ingred)
        else:
            pass
        
    return ingred_list

df['ingredients_parsed'] = df['Ingredients'].apply(ingredinent_parser)

# %%
#we find the most common categories in types 
vocabulary = nltk.FreqDist()

for ingredient_list in df['Type']:
    for ingredients in ingredient_list:
        ingredients = ingredients.split(",")
        vocabulary.update(ingredients)
for word, frequency in vocabulary.most_common(200)[1:]:
    print(f'{word}: {frequency}')

#from this list we have a list of common ingredients to get ride of:
# Out:
# side dish: 1006
# easy: 863
# main dish: 763
# vegetarian: 723
# spicy: 711
# snack: 642
# seafood: 388
# appetizer: 336
# one bowl meal: 325
# beef: 305
# cold: 280
# lunchbox: 259
# soup: 246
# dessert: 229
# preserved side dish: 204
# pork: 171
# fermented: 168
# pancake: 163
# noodle: 157
# chicken: 150
# stew: 149
# anju: 135
# rice: 128
# rice cake: 93
# kimchi: 92
# staple ingredient: 78
# Korean Chinese: 66
# street food: 66
# porridge: 63
# BBQ: 55
# drink: 55
# bakery: 52
# : 50
# mandu: 44
# gimbap: 38
# fried chicken: 37
# pickle: 31
# vegan: 25
# Buddhist temple cuisine: 22
# sundubu-jjigae: 20
# not Korean: 20

# %%
df = pd.read_excel('/Users/seanyoo/Desktop/korean_food_project/src/kreciepe2.0.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              389 non-null    int64
#  1   English Name            389 non-null    object
#  2   Korean Name             389 non-null    object
#  3   Ingredients             389 non-null    object
#  4   Type                    389 non-null    object
#  5   Video                   389 non-null    object
#  6   IngredientsType         389 non-null    object
#  7   IngredientsType_Parsed  389 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 24.4+ KB
